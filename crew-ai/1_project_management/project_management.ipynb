# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 7e5b36b1-9a0b-48fb-90d4-094060466be6                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Task: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Website Project Task Breakdown                                                                             │
# │                                                                                                                 │
# │  #### Task Breakdown with Details, Timelines, Dependencies, and Deliverables                                    │
# │                                                                                                                 │
# │  1. **Create Responsive Design**                                                                                │
# │     - **Description:** Design a layout that adjusts seamlessly across desktop and mobile platforms ensuring     │
# │  usability and accessibility.                                                                                   │
# │     - **Timeline:** 2 weeks (March 1 - March 14)                                                                │
# │     - **Dependencies:** None                                                                                    │
# │     - **Deliverables:** Mockup designs for desktop and mobile.                                                  │
# │                                                                                                                 │
# │  2. **Implement Visual Design/UI**                                                                              │
# │     - **Description:** Develop a modern, visually appealing user interface using clean design principles and    │
# │  branding guidelines.                                                                                           │
# │     - **Timeline:** 2 weeks (March 15 - March 28)                                                               │
# │     - **Dependencies:** Completion of responsive design                                                         │
# │     - **Deliverables:** Fully documented UI designs and stylesheets.                                            │
# │                                                                                                                 │
# │  3. **Develop Navigation System**                                                                               │
# │     - **Description:** Create a user-friendly navigation menu, ensuring an intuitive experience with logical    │
# │  grouping of services.                                                                                          │
# │     - **Timeline:** 1 week (March 29 - April 5)                                                                 │
# │     - **Dependencies:** UI designs need to be implemented                                                       │
# │     - **Deliverables:** Working navigation elements.                                                            │
# │                                                                                                                 │
# │  4. **Create 'About Us' Page**                                                                                  │
# │     - **Description:** Write and design a page that conveys the company's history, mission, and values.         │
# │     - **Timeline:** 1 week (April 6 - April 12)                                                                 │
# │     - **Dependencies:** Design elements for the page must be approved                                           │
# │     - **Deliverables:** Complete 'About Us' webpage.                                                            │
# │                                                                                                                 │
# │  5. **Design 'Services' Page**                                                                                  │
# │     - **Description:** Showcase services with individual descriptions, using engaging visual elements.          │
# │     - **Timeline:** 1 week (April 13 - April 19)                                                                │
# │     - **Dependencies:** 'About Us' page completion and final design approval                                    │
# │     - **Deliverables:** Working 'Services' webpage.                                                             │
# │                                                                                                                 │
# │  6. **Create 'Contact Us' Page**                                                                                │
# │     - **Description:** Implement contact form with backend integration and display a dynamic map for location.  │
# │     - **Timeline:** 1 week (April 20 - April 26)                                                                │
# │     - **Dependencies:** 'Services' page completion                                                              │
# │     - **Deliverables:** Fully functional 'Contact Us' page with forms and maps.                                 │
# │                                                                                                                 │
# │  7. **Develop Blog Section**                                                                                    │
# │     - **Description:** Set up infrastructure for a blog, allowing for content updates and displaying articles.  │
# │     - **Timeline:** 1 week (April 27 - May 3)                                                                   │
# │     - **Dependencies:** All previous pages must be completed                                                    │
# │     - **Deliverables:** Blog layout and functionality.                                                          │
# │                                                                                                                 │
# │  8. **Optimize for Performance & SEO**                                                                          │
# │     - **Description:** Ensure website loading times are fast and implement SEO best practices for visibility.   │
# │     - **Timeline:** 1 week (May 4 - May 10)                                                                     │
# │     - **Dependencies:** All site pages must be functional                                                       │
# │     - **Deliverables:** SEO audit results and optimization report.                                              │
# │                                                                                                                 │
# │  9. **Integrate Social Media & Sharing**                                                                        │
# │     - **Description:** Embed social media buttons and easy sharing options on relevant pages.                   │
# │     - **Timeline:** 1 week (May 11 - May 17)                                                                    │
# │     - **Dependencies:** Completion of optimization stage                                                        │
# │     - **Deliverables:** Social media integration and sharing features.                                          │
# │                                                                                                                 │
# │  10. **Include Testimonials Section**                                                                           │
# │      - **Description:** Design and implement a section for customer testimonials to build trust and             │
# │  credibility.                                                                                                   │
# │      - **Timeline:** 1 week (May 18 - May 24)                                                                   │
# │      - **Dependencies:** Blog section completion                                                                │
# │      - **Deliverables:** Testimonials section on the website.                                                   │
# │                                                                                                                 │
# │  11. **Final QA and Testing**                                                                                   │
# │      - **Description:** Conduct extensive quality assurance tests to ensure all features work as intended       │
# │  across all devices and browsers.                                                                               │
# │      - **Timeline:** 2 weeks (May 25 - June 7)                                                                  │
# │      - **Dependencies:** All other tasks need to be completed                                                   │
# │      - **Deliverables:** QA report and changes based on testing feedback.                                       │
# │                                                                                                                 │
# │  12. **Launch Preparation**                                                                                     │
# │      - **Description:** Prepare for the launch by finalizing all documentation, going through a pre-launch      │
# │  checklist, and ensuring all stakeholders are aligned.                                                          │
# │      - **Timeline:** 1 week (June 8 - June 14)                                                                  │
# │      - **Dependencies:** Completion of QA phase                                                                 │
# │      - **Deliverables:** Go-live checklist, approved launch plan.                                               │
# │                                                                                                                 │
# │  13. **Website Launch**                                                                                         │
# │      - **Description:** Officially launch the website and monitor performance metrics.                          │
# │      - **Timeline:** June 15                                                                                    │
# │      - **Deliverables:** Live website and launch report.                                                        │
# │                                                                                                                 │
# │  ### Project Timeline Visualization                                                                             │
# │                                                                                                                 │
# │  #### Gantt Chart                                                                                               │
# │  ```plaintext                                                                                                   │
# │  | Task                        | Mar  | Apr  | May  | Jun  |                                                    │
# │  |-----------------------------|------|------|------|------|                                                    │
# │  | Create Responsive Design     |XXXXXX|      |      |      |                                                   │
# │  | Implement Visual Design/UI   |      |XXXXXX|      |      |                                                   │
# │  | Develop Navigation System     |      |      | XXXXXX|      |                                                 │
# │  | Create 'About Us' Page       |      |      | XXXXXX|      |                                                  │
# │  | Design 'Services' Page       |      |      | XXXXXX|      |                                                  │
# │  | Create 'Contact Us' Page     |      |      | XXXXXX|      |                                                  │
# │  | Develop Blog Section         |      |      |XXXXXX |      |                                                  │
# │  | Optimize for Performance & SEO|      |      |XXXXXX |      |                                                 │
# │  | Integrate Social Media & Sharing|    |      |XXXXXX |      |                                                 │
# │  | Include Testimonials Section  |      |      |      |XXXXXX|                                                  │
# │  | Final QA and Testing         |      |      |XXXXXX |XXXXX |                                                  │
# │  | Launch Preparation           |      |      |      |XXXXXX|                                                   │
# │  | Website Launch               |      |      |      |   X  |                                                   │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  ### Team Responsibilities                                                                                      │
# │                                                                                                                 │
# │  - **John Doe (Project Manager):** Oversight of project, task assignments, and timeline adherence.              │
# │  - **Jane Doe (Software Engineer):** Backend development including form integration, blog setup, and ensuring   │
# │  site performance.                                                                                              │
# │  - **Bob Smith (Designer):** Visual elements, UI design, and overall aesthetics of the website.                 │
# │  - **Alice Johnson (QA Engineer):** Quality assurance testing and reporting.                                    │
# │  - **Tom Brown (QA Engineer):** Additional testing, focusing on performance and SEO metrics.                    │
# │                                                                                                                 │
# │  This comprehensive plan aims to ensure a successful website launch for the small business while managing all   │
# │  aspects meticulously. Each task is designed to build on the previous, ensuring a cohesive and well-integrated  │
# │  final product.                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 2ebccba6-44b5-4db7-aee6-046a3eca51b3                                                                     │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Website Project Estimation Report                                                                          │
# │                                                                                                                 │
# │  This detailed report evaluates each task within the Website project. It outlines the estimated time,           │
# │  resources, effort, and risks associated with each task, ensuring comprehensive planning for an efficient and   │
# │  successful project.                                                                                            │
# │                                                                                                                 │
# │  #### Task Breakdown Estimation                                                                                 │
# │                                                                                                                 │
# │  1. **Create Responsive Design**                                                                                │
# │     - **Estimated Time:** 2 weeks (March 1 - March 14)                                                          │
# │     - **Resources Required:** 1 Designer, 1 Project Manager                                                     │
# │     - **Effort:** 80 hours total                                                                                │
# │     - **Risks:** Design not meeting accessibility standards could require rework.                               │
# │                                                                                                                 │
# │  2. **Implement Visual Design/UI**                                                                              │
# │     - **Estimated Time:** 2 weeks (March 15 - March 28)                                                         │
# │     - **Resources Required:** 1 Designer, 1 Software Engineer                                                   │
# │     - **Effort:** 80 hours total                                                                                │
# │     - **Risks:** Misalignment on branding may lead to inconsistencies; design revisions could push timelines.   │
# │                                                                                                                 │
# │  3. **Develop Navigation System**                                                                               │
# │     - **Estimated Time:** 1 week (March 29 - April 5)                                                           │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Poorly structured navigation may increase user drop-off rates.                                 │
# │                                                                                                                 │
# │  4. **Create 'About Us' Page**                                                                                  │
# │     - **Estimated Time:** 1 week (April 6 - April 12)                                                           │
# │     - **Resources Required:** 1 Designer, 1 Content Writer                                                      │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Delays in content approval materials could stall project progress.                             │
# │                                                                                                                 │
# │  5. **Design 'Services' Page**                                                                                  │
# │     - **Estimated Time:** 1 week (April 13 - April 19)                                                          │
# │     - **Resources Required:** 1 Designer                                                                        │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Client feedback could lead to rework; potential scope creep.                                   │
# │                                                                                                                 │
# │  6. **Create 'Contact Us' Page**                                                                                │
# │     - **Estimated Time:** 1 week (April 20 - April 26)                                                          │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Integration issues with backend functionality (forms and maps) could cause delays.             │
# │                                                                                                                 │
# │  7. **Develop Blog Section**                                                                                    │
# │     - **Estimated Time:** 1 week (April 27 - May 3)                                                             │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Future content management issues if the setup is not robust.                                   │
# │                                                                                                                 │
# │  8. **Optimize for Performance & SEO**                                                                          │
# │     - **Estimated Time:** 1 week (May 4 - May 10)                                                               │
# │     - **Resources Required:** 1 Software Engineer, 1 QA Engineer                                                │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Insufficient optimization could lead to poor search engine rankings.                           │
# │                                                                                                                 │
# │  9. **Integrate Social Media & Sharing**                                                                        │
# │     - **Estimated Time:** 1 week (May 11 - May 17)                                                              │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours total                                                                                │
# │     - **Risks:** Integration failures could impact user engagement metrics.                                     │
# │                                                                                                                 │
# │  10. **Include Testimonials Section**                                                                           │
# │      - **Estimated Time:** 1 week (May 18 - May 24)                                                             │
# │      - **Resources Required:** 1 Designer, 1 Software Engineer                                                  │
# │      - **Effort:** 40 hours total                                                                               │
# │      - **Risks:** Changes in client requirements could lead to misalignment.                                    │
# │                                                                                                                 │
# │  11. **Final QA and Testing**                                                                                   │
# │      - **Estimated Time:** 2 weeks (May 25 - June 7)                                                            │
# │      - **Resources Required:** 2 QA Engineers                                                                   │
# │      - **Effort:** 160 hours total                                                                              │
# │      - **Risks:** Undetected bugs could affect user experience post-launch.                                     │
# │                                                                                                                 │
# │  12. **Launch Preparation**                                                                                     │
# │      - **Estimated Time:** 1 week (June 8 - June 14)                                                            │
# │      - **Resources Required:** 1 Project Manager, 1 QA Engineer                                                 │
# │      - **Effort:** 40 hours total                                                                               │
# │      - **Risks:** Incomplete checklists could lead to issues during the product launch.                         │
# │                                                                                                                 │
# │  13. **Website Launch**                                                                                         │
# │      - **Estimated Time:** 1 day (June 15)                                                                      │
# │      - **Resources Required:** Entire Project Team                                                              │
# │      - **Effort:** 8 hours total                                                                                │
# │      - **Risks:** Launch day issues (server failures, performance problems) could impede project success.       │
# │                                                                                                                 │
# │  ### Summary of Risks                                                                                           │
# │  - **Timeline Delays:** Changes in client requirements or unforeseen complications can impact task timelines.   │
# │  - **Quality Assurance Issues:** Potential undiscovered bugs could have ramifications after launch.             │
# │  - **Resource Management:** Flexibility and efficiency of team members can mitigate risks throughout the        │
# │  project's lifecycle.                                                                                           │
# │                                                                                                                 │
# │  By leveraging historical data, assessing task complexity, and accounting for potential risks, this report      │
# │  serves as a robust framework for estimating each task's duration, resources, and efforts. This integrated      │
# │  approach is designed to ensure that the website project is delivered efficiently and on budget.                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 4b7f7cb1-747c-4453-bbd0-4bb7812f73d8                                                                     │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Task: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  {                                                                                                              │
# │    "tasks": [                                                                                                   │
# │      {                                                                                                          │
# │        "task_name": "Create Responsive Design",                                                                 │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith", "John Doe"]                                                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement Visual Design/UI",                                                               │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith", "Jane Doe"]                                                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop Navigation System",                                                                │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create 'About Us' Page",                                                                   │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith"]                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Design 'Services' Page",                                                                   │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith"]                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create 'Contact Us' Page",                                                                 │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop Blog Section",                                                                     │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Optimize for Performance & SEO",                                                           │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe", "Alice Johnson", "Tom Brown"]                                         │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Integrate Social Media & Sharing",                                                         │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Include Testimonials Section",                                                             │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith", "Jane Doe"]                                                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Final QA and Testing",                                                                     │
# │        "estimated_time_hours": 160,                                                                             │
# │        "required_resources": ["Alice Johnson", "Tom Brown"]                                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Launch Preparation",                                                                       │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["John Doe", "Alice Johnson"]                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Website Launch",                                                                           │
# │        "estimated_time_hours": 8,                                                                               │
# │        "required_resources": ["John Doe", "Jane Doe", "Bob Smith", "Alice Johnson", "Tom Brown"]                │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "milestones": [                                                                                              │
# │      {                                                                                                          │
# │        "milestone_name": "Design Phase",                                                                        │
# ...
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 7aa31a1b-6f14-4d92-a29b-f6e8f41d5a6b                                                                     │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 7e5b36b1-9a0b-48fb-90d4-094060466be6                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: {                                                                                                │
# │    "tasks": [                                                                                                   │
# │      {                                                                                                          │
# │        "task_name": "Create Responsive Design",                                                                 │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith", "John Doe"]                                                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement Visual Design/UI",                                                               │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith", "Jane Doe"]                                                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop Navigation System",                                                                │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create 'About Us' Page",                                                                   │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith"]                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Design 'Services' Page",                                                                   │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith"]                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create 'Contact Us' Page",                                                                 │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop Blog Section",                                                                     │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Optimize for Performance & SEO",                                                           │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe", "Alice Johnson", "Tom Brown"]                                         │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Integrate Social Media & Sharing",                                                         │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Include Testimonials Section",                                                             │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith", "Jane Doe"]                                                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Final QA and Testing",                                                                     │
# │        "estimated_time_hours": 160,                                                                             │
# │        "required_resources": ["Alice Johnson", "Tom Brown"]                                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Launch Preparation",                                                                       │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["John Doe", "Alice Johnson"]                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Website Launch",                                                                           │
# │        "estimated_time_hours": 8,                                                                               │
# │        "required_resources": ["John Doe", "Jane Doe", "Bob Smith", "Alice Johnson", "Tom Brown"]                │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "milestones": [                                                                                              │
# │      {                                                                                                          │
# │        "milestone_name": "Design Phase",                                                                        │
# │        "tasks": [                                                                                               │
# │          "Create Responsive Design",                                                                            │
# │          "Implement Visual Design/UI"                                                                           │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Development Phase",                                                                   │
# │        "tasks": [                                                                                               │
# │          "Develop Navigation System",                                                                           │
# │          "Create 'About Us' Page",                                                                              │
# │          "Design 'Services' Page",                                                                              │
# │          "Create 'Contact Us' Page",                                                                            │
# │          "Develop Blog Section"                                                                                 │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Optimization Phase",                                                                  │
# │        "tasks": [                                                                                               │
# │          "Optimize for Performance & SEO",                                                                      │
# │          "Integrate Social Media & Sharing"                                                                     │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Preparation Phase",                                                                   │
# │        "tasks": [                                                                                               │
# │          "Include Testimonials Section",                                                                        │
# │          "Final QA and Testing",                                                                                │
# │          "Launch Preparation"                                                                                   │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Launch Phase",                                                                        │
# │        "tasks": [                                                                                               │
# │          "Website Launch"                                                                                       │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0012
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          7971           4898                     0               3073
#
#    successful_requests
# 0                    3

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith', 'John Doe']},
#   {'task_name': 'Implement Visual Design/UI',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Develop Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'About Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Design 'Services' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Create 'Contact Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop Blog Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize for Performance & SEO',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Integrate Social Media & Sharing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Final QA and Testing',
#    'estimated_time_hours': 160.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Launch Preparation',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe', 'Alice Johnson']},
#   {'task_name': 'Website Launch',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['John Doe',
#     'Jane Doe',
#     'Bob Smith',
#     'Alice Johnson',
#     'Tom Brown']}],
#  'milestones': [{'milestone_name': 'Design Phase',
#    'tasks': ['Create Responsive Design', 'Implement Visual Design/UI']},
#   {'milestone_name': 'Development Phase',
#    'tasks': ['Develop Navigation System',
#     "Create 'About Us' Page",
#     "Design 'Services' Page",
#     "Create 'Contact Us' Page",
#     'Develop Blog Section']},
#   {'milestone_name': 'Optimization Phase',
#    'tasks': ['Optimize for Performance & SEO',
#     'Integrate Social Media & Sharing']},
#   {'milestone_name': 'Preparation Phase',
#    'tasks': ['Include Testimonials Section',
#     'Final QA and Testing',
#     'Launch Preparation']},
#   {'milestone_name': 'Launch Phase', 'tasks': ['Website Launch']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_23ffe th {
#   font-size: 120%;
# }
# #T_23ffe  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_23ffe" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23ffe_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_23ffe_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_23ffe_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23ffe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23ffe_row0_col0" class="data row0 col0" >Create Responsive Design</td>
#       <td id="T_23ffe_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_23ffe_row0_col2" class="data row0 col2" >['Bob Smith', 'John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23ffe_row1_col0" class="data row1 col0" >Implement Visual Design/UI</td>
#       <td id="T_23ffe_row1_col1" class="data row1 col1" >80.000000</td>
#       <td id="T_23ffe_row1_col2" class="data row1 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23ffe_row2_col0" class="data row2 col0" >Develop Navigation System</td>
#       <td id="T_23ffe_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_23ffe_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23ffe_row3_col0" class="data row3 col0" >Create 'About Us' Page</td>
#       <td id="T_23ffe_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_23ffe_row3_col2" class="data row3 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23ffe_row4_col0" class="data row4 col0" >Design 'Services' Page</td>
#       <td id="T_23ffe_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_23ffe_row4_col2" class="data row4 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_23ffe_row5_col0" class="data row5 col0" >Create 'Contact Us' Page</td>
#       <td id="T_23ffe_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_23ffe_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_23ffe_row6_col0" class="data row6 col0" >Develop Blog Section</td>
#       <td id="T_23ffe_row6_col1" class="data row6 col1" >40.000000</td>
#       <td id="T_23ffe_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_23ffe_row7_col0" class="data row7 col0" >Optimize for Performance & SEO</td>
#       <td id="T_23ffe_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_23ffe_row7_col2" class="data row7 col2" >['Jane Doe', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_23ffe_row8_col0" class="data row8 col0" >Integrate Social Media & Sharing</td>
#       <td id="T_23ffe_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_23ffe_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_23ffe_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_23ffe_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_23ffe_row9_col2" class="data row9 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_23ffe_row10_col0" class="data row10 col0" >Final QA and Testing</td>
#       <td id="T_23ffe_row10_col1" class="data row10 col1" >160.000000</td>
#       <td id="T_23ffe_row10_col2" class="data row10 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_23ffe_row11_col0" class="data row11 col0" >Launch Preparation</td>
#       <td id="T_23ffe_row11_col1" class="data row11 col1" >40.000000</td>
#       <td id="T_23ffe_row11_col2" class="data row11 col2" >['John Doe', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_23ffe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_23ffe_row12_col0" class="data row12 col0" >Website Launch</td>
#       <td id="T_23ffe_row12_col1" class="data row12 col1" >8.000000</td>
#       <td id="T_23ffe_row12_col2" class="data row12 col2" >['John Doe', 'Jane Doe', 'Bob Smith', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_317a8 th {
#   font-size: 120%;
# }
# #T_317a8  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_317a8" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_317a8_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_317a8_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_317a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_317a8_row0_col0" class="data row0 col0" >Design Phase</td>
#       <td id="T_317a8_row0_col1" class="data row0 col1" >['Create Responsive Design', 'Implement Visual Design/UI']</td>
#     </tr>
#     <tr>
#       <th id="T_317a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_317a8_row1_col0" class="data row1 col0" >Development Phase</td>
#       <td id="T_317a8_row1_col1" class="data row1 col1" >['Develop Navigation System', "Create 'About Us' Page", "Design 'Services' Page", "Create 'Contact Us' Page", 'Develop Blog Section']</td>
#     </tr>
#     <tr>
#       <th id="T_317a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_317a8_row2_col0" class="data row2 col0" >Optimization Phase</td>
#       <td id="T_317a8_row2_col1" class="data row2 col1" >['Optimize for Performance & SEO', 'Integrate Social Media & Sharing']</td>
#     </tr>
#     <tr>
#       <th id="T_317a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_317a8_row3_col0" class="data row3 col0" >Preparation Phase</td>
#       <td id="T_317a8_row3_col1" class="data row3 col1" >['Include Testimonials Section', 'Final QA and Testing', 'Launch Preparation']</td>
#     </tr>
#     <tr>
#       <th id="T_317a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_317a8_row4_col0" class="data row4 col0" >Launch Phase</td>
#       <td id="T_317a8_row4_col1" class="data row4 col1" >['Website Launch']</td>
#     </tr>
#   </tbody>
# </table>
